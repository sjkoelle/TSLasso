# %%
import matplotlib
matplotlib.use('Agg')
import os
import datetime
import numpy as np
import dill as pickle
import random
import sys

workingdirectory = os.popen('git rev-parse --show-toplevel').read()[:-1]
sys.path.append(workingdirectory)
os.chdir(workingdirectory)

from codes.geometer.RiemannianManifold import RiemannianManifold

# %%
asdf.shape
# Out:
# (26979, 50)

# %%
asdf = np.load('/Users/samsonkoelle/Desktop/eMDA-H-H-H_anglespca_pca50.npy')
b = RiemannianManifold(asdf,2)
diffusion_time = 5
dim = 2
b.geom = b.compute_geom(diffusion_time, 500)
c = b.get_embedding3(b.geom, 5, diffusion_time, dim)
# Out:
# initializing Geometry
# executing laplacian.compute_laplacian_matrix
# executing Laplacian.laplacian_matrix
# pre _compute_laplacian
# executing GeometricLaplacian._compute_laplacian
# executing _normalize_laplacian
# executing _normalize_laplacian
# post _compute_laplacian
# executing laplacian.compute_laplacian_matrix
# executing Laplacian.laplacian_matrix
# pre _compute_laplacian
# executing GeometricLaplacian._compute_laplacian
# executing _normalize_laplacian
# executing _normalize_laplacian
# post _compute_laplacian
# /Users/samsonkoelle/anaconda3/envs/py35021518/lib/python3.5/site-packages/megaman/geometry/rmetric.py:95: RuntimeWarning: divide by zero encountered in reciprocal
#   Einv = E**(-1)

# %%
# %matplotlib inline
n = c.data.shape[0]
c.plot([0,1],list(range(n)),np.ones(n), .1,.1, None)

# %%
# %matplotlib inline
n = c.data.shape[0]
c.plot([0,4],list(range(n)),np.ones(n), .1,.1, None)

# %%
# %matplotlib inline
n = c.data.shape[0]
c.plot([0,1],list(range(n)),np.linspace(0,1,n), .1,1, None)

# %%
# %matplotlib inline
n = c.data.shape[0]
c.plot([0,1,4],list(range(n)),np.linspace(0,1,n), .1,1, None)

# %%
help(c.plot)
# Out:
# Help on method plot in module codes.geometer.RiemannianManifold:
#
# plot(axes, selected_points, c, s, alpha, filename, cbar=True) method of codes.geometer.RiemannianManifold.RiemannianManifold instance
