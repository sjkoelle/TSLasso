# %%
import torch
import numpy as np
import os
#workingdirectory = '/Users/samsonkoelle/Downloads/manigrad-100818/mani-samk-gradients'
workingdirectory = os.popen('git rev-parse --show-toplevel').read()[:-1]
os.chdir(workingdirectory)
from codes.otherfunctions.data_stream_custom_range import data_stream_custom_range

# %%
    def torchComputeAngle(poses):
        combos = torch.tensor([[0, 1], [1, 2], [2, 0]])
        ab = torch.norm(poses[combos[0, 0], :] - poses[combos[0, 1], :])
        bc = torch.norm(poses[combos[1, 0], :] - poses[combos[1, 1], :])
        ca = torch.norm(poses[combos[2, 0], :] - poses[combos[2, 1], :])
        output = torch.acos((ab ** 2 - bc ** 2 + ca ** 2) / (2 * ab * ca))
        return (output)

    def torchCompute3angles(position):
        angles = np.ones(3)
        gradients = np.zeros((3, position.shape[0], 3))
        for i in range(3):
            #print(i)
            poses = torch.tensor(position[[i, (i + 1) % 3, (i + 2) % 3], :], requires_grad=True)
            tempang = torchComputeAngle(poses)
            tempang.backward()
            angles[i] = tempang.detach().numpy()
            gradients[i] = poses.grad[[(2 * i) % 3, (2 * i + 1) % 3, (2 * i + 2) % 3], :]
            # del(poses)
        return(angles, gradients)

    def reshapepointdata(pointdata, atoms3):
        natoms = len(np.unique(atoms3))
        output = np.zeros((pointdata.shape[0] * pointdata.shape[1], natoms * 3))
        for i in range(pointdata.shape[0]):
            for j in range(pointdata.shape[1]):
                for k in range(pointdata.shape[2]):
                    for l in range(pointdata.shape[3]):
                        # print(atoms3[k]*3 + l)
                        output[i * 3 + j, atoms3[i][k] * 3 + l] = pointdata[i, j, k, l]
        return(output)

    def get_wilson(selind, atoms3, tdata):
        natoms = len(np.unique(atoms3))
        jacobien = np.zeros((len(selind), len(atoms3) * 3, natoms * 3))
        for i in range(len(selind)):
            pointdata = tdata[i * len(atoms3): (i + 1) * len(atoms3)]
            jacobien[i] = reshapepointdata(pointdata, atoms3)
        return(jacobien)

    def get_internal_projector(natoms, jacobien, selind):
        nnonzerosvd = 3 * natoms - 7
        internalprojector = np.zeros((len(selind), jacobien.shape[1], nnonzerosvd))
        for i in range(len(selind)):
            # when rescaling vectors, big directions must be shrunk... this is the riemannian bundle and should be treated as such
            asdf = np.linalg.svd(jacobien[i])
            #internalprojector[i] = (asdf[0][:, :nnonzerosvd] * asdf[1][:nnonzerosvd] ** (-1))
            internalprojector[i] = (asdf[0][:, :nnonzerosvd] )
        return (internalprojector)

    def get_dw(cores,atoms3,natoms, selected_points):
        positions = experiment.positions
        p = Pool(cores)
        n = len(selected_points)
        results = p.map(lambda i: torchCompute3angles(position=positions[i[0], atoms3[i[1]], :]),
                        data_stream_custom_range(selected_points, len(atoms3)))
        tdata = np.asarray([results[i][1] for i in range(n * len(atoms3))])
        # for i in range(len(selected_points)):
        #     pointdata = tdata[i * len(atoms3): (i + 1) * len(atoms3)]
        jacobien = get_wilson(selected_points, atoms3, tdata)
        internalprojector = get_internal_projector(natoms, jacobien, selected_points)
        return(internalprojector)

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

def get_l2loss_perobservation(coeffs,ys,xs):
	nlam = coeffs.shape[0]
	n = coeffs.shape[2]
	lossermans = np.zeros((nlam,n))
	for l in range(nlam):
		for i in range(n):
			lossermans[l,i] = np.sum((ys[i].transpose() - np.matmul(coeffs[l][:,i,:],xs[i,:,:]))**2)
	return(lossermans)



def construct_X_js_subset(self,dg_M,selind):
    dg_M_subset = np.zeros(dg_M.shape)
    dg_M_subset[:,selind,:] = dg_M[:,selind,:]
    output = self.construct_X_js(dg_M_subset)
    return(output)

def get_reconstructed_vectors(coeff,dg_M):
    dimnoise = dg_M.shape[2]
    m = coeff.shape[0]
    n =  coeff.shape[1]
    yhat = np.zeros((n,dimnoise, m))
    for i in range(n):
        yhat[i] = np.matmul(coeff[:,i,:],dg_M[i,:,:]).transpose()
    return(yhat)

# %%
from pathos.multiprocessing import ProcessingPool as Pool

# %%
#rootdirectory = '/Users/samsonkoelle/Downloads/manigrad-100818/mani-samk-gradients'
#f = open(rootdirectory + '/code/source/packagecontrol.py')
#source = f.read()
#exec(source)
#f = open(rootdirectory + '/code/source/sourcecontrol.py')
#source = f.read()
#exec(source)
#f = open(rootdirectory + '/code/source/RigidEthanol.py')
#source = f.read()
#exec(source)
import os
workingdirectory = '/Users/samsonkoelle/Downloads/manigrad-100818/mani-samk-gradients'
os.chdir(workingdirectory)
from codes.experimentclasses.RigidEthanolAngles import RigidEthanolAngles
from codes.experimentclasses.EthanolAngles import EthanolAngles
from codes.geometer.RiemannianManifold import RiemannianManifold
from codes.geometer.TangentBundle import TangentBundle
from codes.geometer.ShapeSpace import ShapeSpace
import numpy as np

#set parameters
n = 50000 #number of data points to simulate
nsel = 100 #number of points to analyze with lasso
itermax = 10000 #maximum iterations per lasso run
tol = 1e-10 #convergence criteria for lasso
lambdas = np.asarray([0,10,100,1000,10000], dtype = np.float16)#lambda values for lasso
n_neighbors = 100 #number of neighbors in megaman
n_components = 3 #number of embedding dimensions (diffusion maps)
diffusion_time = 1. #diffusion time controls gaussian kernel radius per gradients paper
dim = 2 #manifold dimension
cores = 3 #number of cores for parallel processing
cor = 0.0 #correlation for noise
var = 0.00001 #variance scaler for noise
ii = np.asarray([0,0,0,0,1,1,1,2]) # atom adjacencies for dihedral angle computation
jj = np.asarray([1,2,3,4,5,6,7,8])

#run experiment
atoms4 = np.asarray([[6,1,0,4],[4,0,2,8],[7,6,5,1],[3,0,2,4]],dtype = int)
experiment = EthanolAngles(dim, ii,jj,cores, atoms4)
experiment.M = experiment.load_data() #if noise == False then noise parameters are overriden
experiment.q = n_components
experiment.M.geom = experiment.M.compute_geom(diffusion_time, n_neighbors)
experiment.N = experiment.M.get_embedding3(experiment.M.geom, n_components, diffusion_time, dim)
#experiment.M.selected_points = np.random.choice(list(range(n)),nsel,replace = False)
experiment.M.selected_points = np.asarray([ 911, 8873, 3223, 1867, 5243, 6188, 2567, 8330, 4615, 4561, 1431,
       4218, 7020,   39, 1542, 3258, 7355, 5396, 5252, 2863,  114, 6123,
       1259, 3568, 2403, 5681, 2340, 5062, 3205, 1082, 3383, 4840, 9009,
       5246,  140, 9999, 6659, 2759, 6980, 1054, 4552, 5233,  367, 9262,
       7272, 2930, 7055, 8931, 4999, 5829, 7530, 3487, 1001, 4592, 8429,
       3572,  312, 4158, 6723,  217, 6387, 6007, 3569, 9479, 9645, 5041,
       3923, 6205,   41, 3443, 1655, 4000, 1292, 4443, 5100, 7193, 5096,
       6689, 4729, 9424, 7672, 3565,  289, 2224, 1898,  400, 8428, 9752,
       2767, 1551,  837, 8257, 6307, 8820, 7884, 7814, 8203, 3468, 4826,
       2824])

tangent_bases = experiment.M.get_wlpca_tangent_sel(experiment.M,experiment.M.selected_points)
subM = RiemannianManifold(experiment.M.data[experiment.M.selected_points], dim)
subM.tb = TangentBundle(subM, tangent_bases)
experiment.N.tangent_bundle = TangentBundle(experiment.N, experiment.N.geom.rmetric.embedding_eigenvectors)
experiment.df_M = experiment.get_dF_js_idM(experiment.M, experiment.N, subM.tb, experiment.N.tangent_bundle,experiment.M.selected_points)
experiment.dg_x = experiment.get_dx_g_full(experiment.M.data[experiment.M.selected_points])
experiment.W = ShapeSpace(experiment.positions, experiment.M.data)
experiment.dw = experiment.W.get_dw(cores, experiment.atoms3, experiment.natoms, experiment.M.selected_points)
experiment.dg_w = experiment.project(experiment.dw, experiment.dg_x)
tb_w_tangent_bases = experiment.project(experiment.dw, np.swapaxes(subM.tb.tangent_bases,1,2))
experiment.dgw_norm = experiment.normalize(experiment.dg_w)
experiment.dg_M = experiment.project(np.swapaxes(tb_w_tangent_bases,1,2), experiment.dgw_norm)
experiment.xtrain, experiment.groups = experiment.construct_X_js(experiment.dg_M)
experiment.ytrain = experiment.construct_Y_js(experiment.df_M)
experiment.coeffs = experiment.get_betas_spam2(experiment.xtrain, experiment.ytrain, experiment.groups,lambdas,nsel,experiment.q,itermax,tol)
gnames = [str(i) for i in range(experiment.p)]
fnames = [str(i) for i in range(experiment.q)]
file = 'Figures/ethanol05goodplots' + str(itermax)
title= r"$\displaystyle$"
xtitle = r"$\displaystyle \lambda $"
# Out:
# /Users/samsonkoelle/Downloads/manigrad-100818/mani-samk-gradients
# initializing Geometry
# executing laplacian.compute_laplacian_matrix
# executing Laplacian.laplacian_matrix
# pre _compute_laplacian
# executing GeometricLaplacian._compute_laplacian
# executing _normalize_laplacian
# executing _normalize_laplacian
# post _compute_laplacian
# executing laplacian.compute_laplacian_matrix
# executing Laplacian.laplacian_matrix
# pre _compute_laplacian
# executing GeometricLaplacian._compute_laplacian
# executing _normalize_laplacian
# executing _normalize_laplacian
# post _compute_laplacian
# /Users/samsonkoelle/anaconda3/envs/py35021518/lib/python3.5/site-packages/megaman/geometry/rmetric.py:95: RuntimeWarning: divide by zero encountered in reciprocal
#   Einv = E**(-1)

# %%
# Out:
# (50000, 252)

# %%
dg_M_smooth_copy = experiment.dg_M.copy()
dg_phi_M = np.einsum(
    'ijk,imk->ijm', 
    experiment.N.tangent_bundle.tangent_bases[experiment.M.selected_points], 
    dg_M_smooth_copy)

# %%
import matplotlib.pyplot as plt

# %%
    def plot_tangent_arrows(data,show_pts, arrow_pts, arrows,axes,  arrow_scaler = .1, colors = None):
        #data = self.manifold.data
        #tangent_bases = self.tangent_bases
        #dim  = self.manifold.dim
        #colors = new color for every tan basis vector
        if colors == None:
            colors = np.repeat('black',arrows.shape[2])
        if len(axes) == 3:
            fig = plt.figure(figsize=(15,5))
            ax = fig.add_subplot(1, 1,1, projection='3d')
            cax = ax.scatter(data[show_pts, 0], data[show_pts, 1], data[show_pts,2], s=  .5, alpha=.1, marker = '.')
            for i in range(len(arrow_pts)):
                for j in range(arrows.shape[2]):
                    #print(i)
                    X,Y,Z = data[arrow_pts[i],:]
                    U,V,W = arrows[i,:,j] 
                    ax.quiver(X,Y,Z,U,V,W, alpha = .5, color = colors[j])
                    #U, V, W = tangent_bases[i,:,1] * arrow_scaler
                    #ax.quiver(X,Y,Z,U,V,W, alpha = .5, color = 'r')
            ax.set_axis_off()
        if len(axes) == 2:
            fig = plt.figure(figsize=plt.figaspect(.5))
            ax = fig.add_subplot(1, 1,1)
            cax = ax.scatter(data[show_pts, 0], data[show_pts, 1], s=  .5, alpha=.1, marker = '.')
            for i in range(len(arrow_pts)):
                for j in range(arrows.shape[2]):
                    #print(i)
                    X,Y = data[arrow_pts[i],:]
                    U,V = arrows[i,:,j] * arrow_scaler
                    ax.quiver(X,Y,U,V, alpha = .5,angles='xy', scale_units='xy', scale=1, color = colors[j])
        #fig.colorbar(cax)

# %%
#arrows.shape

# %%
# %matplotlib notebook
data = experiment.N.data
show_pts = list(range(50000))
arrow_pts = experiment.M.selected_points
arrows = dg_phi_M[:,:,:2]
axes = [0,1,2]
arrow_scaler = .1
plot_tangent_arrows(data,show_pts, arrow_pts, arrows,[0,1,2], arrow_scaler = 1, colors = ['black','red'])
# Out:
# <img src="data:image/png;base64,..." width="1079.999976591631">

# %%
plot_tangent_arrows(data,list(range(5000)), list(range(100)), arrows,[0,1,2], arrow_scaler = .25, colors = ['black','red'])
# Out:
# <img src="data:image/png;base64,..." width="1079.999976591631">

# %%
data = experiment.N.data
show_pts = list(range(50000))
arrow_pts = experiment.M.selected_points
arrows = dg_phi_M[:,:,2:]
axes = [0,1,2]
arrow_scaler = .1
plot_tangent_arrows(data,show_pts, arrow_pts, arrows,[0,1,2], arrow_scaler = 1)
# Out:
# <img src="data:image/png;base64,..." width="1079.999976591631">

# %%
import megaman
import megaman.plotter

# %%
data = experiment.N.data
metric = experiment.N.geom.rmetric.g_metric_embedding / 10000000000000
def plot_metric_ellipses(data, metric):
    if data.shape[1] == 3:
        fig = plt.figure(figsize=plt.figaspect(.5))
        ax = fig.add_subplot(1, 1,1, projection='3d')
        ax.scatter(data[:, 0], data[:, 1], data[:, 2],s = .1, alpha = .1)
        ax.set_axis_off()
        megaman.plotter.covar_plotter3.covar_plotter3d_matplotlib(data, metric, range(100), ax, np.repeat('green',100))
        
plot_metric_ellipses(data, metric)
# Out:
# <img src="data:image/png;base64,..." width="575.9090784265978">
# /Users/samsonkoelle/anaconda3/envs/py35021518/lib/python3.5/site-packages/megaman/plotter/utils.py:13: FutureWarning: Be careful in using megaman.plotter modules API will change in the next release.
#   FutureWarning

# %%
experiment.xtrain_sel, experiment.groups_sel = experiment.construct_X_js_subset(experiment.dg_M,[0,1])
lams = np.asarray([0], dtype = np.float64)

# %%
experiment.xtrain_sel.shape
# Out:
# (600, 1200)

# %%
testcoeffs_sel = experiment.get_betas_spam2(experiment.xtrain_sel, experiment.ytrain, experiment.groups_sel,lams[0:1],100,experiment.q,10000,tol)

# %%
yhats = get_reconstructed_vectors(testcoeffs_sel[0],experiment.dg_M)

# %%
def plot_tangent_vecs(cords, ax_sel, selected_points, dims,colors = None):
    cords_sel = cords[selected_points]
    if colors == None:
        colors = np.repeat('black',cords.shape[1])
    
    if len(ax_sel) == 3:
        2+2
    if len(ax_sel) == 2:
        fig = plt.figure(figsize=(15,10)) 
        for ix, dg_M_i in enumerate(cords_sel):
            #print(ix)
            ax = fig.add_subplot(dims[0], dims[1],ix+1)
            #ax.set_axis_off()
            xs = np.concatenate([dg_M_i[:,0],[0]])
            ys = np.concatenate([dg_M_i[:,1],[0]])
            xrange = xs.max()- xs.min()
            yrange = ys.max()- ys.min()
            ax.set_xlim(xs.min()- .25*xrange ,xs.max() + .25*xrange)
            ax.set_ylim(ys.min()- .25*yrange,ys.max()+ .25*yrange)
            for i in range(len(xs) - 1): 
                #print(xs[i]**2 + ys[i]**2)
                ax.quiver(0,0,xs[i],ys[i], alpha = .5,angles='xy', scale_units='xy', scale=1, color = colors[i])
            ax.set_axis_off()

# %%
plot_tangent_vecs(experiment.dg_M, [0,1], [5], [1,1], ['red','black','blue','green'])

# %%
plot_tangent_vecs(np.swapaxes(experiment.df_M,1,2), [0,1], [1], [1,1], ['red','red','red'])

# %%
plot_tangent_vecs(np.swapaxes(experiment.df_M,1,2), [0,1], list(range(6)), [3,2], ['red','red','red'])

# %%
plot_tangent_vecs(np.swapaxes(np.concatenate((experiment.df_M,yhats),2),1,2), [0,1], list(range(6)), [2,3], ['red','red','red','black','black','black'])

# %%
plot_tangent_vecs(experiment.dg_M, [0,1], list(range(6)), [2,3], ['red','black','blue','green'])

# %%
plot_tangent_vecs(np.swapaxes(np.concatenate((experiment.df_M,yhats),2),1,2), [0,1], list(range(6)), [2,3], ['red','red','red','black','black','black'])

# %%
plot_tangent_vecs(np.swapaxes(np.concatenate((experiment.df_M,yhats),2),1,2), [0,1], [4], [1,1], ['red','red','red','black','black','black'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-245-638f43193b8d> in <module>()
# ----> 1 plot_tangent_vecs(np.swapaxes(np.concatenate((experiment.df_M,yhats),2),1,2), [0,1], [4], [1,1], ['red','red','red','black','black','black'])
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
experiment.df_M[4]
# Out:
# array([[ 1632.79483584, -1365.25338213,  1184.80635464],
#        [-2203.49397061,  2042.34750354,  1129.48809936]])

# %%
yhats[4]
# Out:
# array([[-16257.64560503,  16764.48705645,  58251.51936053],
#        [-24899.5592165 ,  25059.57259805,  73352.87316008]])

# %%
experiment.xtrain_sel, experiment.groups_sel = experiment.construct_X_js_subset(experiment.dg_M[4:5],[0,1])
lams = np.asarray([0], dtype = np.float64)
experiment.ytrain = experiment.construct_Y_js(experiment.df_M[4:5])
testcoeffs_sel2 = experiment.get_betas_spam2(experiment.xtrain_sel, experiment.ytrain, experiment.groups_sel,lams[0:1],1,experiment.q,10000000,tol)
testcoeffs_sel2sam = experiment.get_betas_sam(experiment.xtrain_sel, experiment.ytrain, experiment.groups_sel,lams[0:1],1,experiment.q,20000,tol,.05)
yhats2sam = get_reconstructed_vectors(testcoeffs_sel2sam[0],experiment.dg_M[4:5])
# Out:
# (12,)

# %%
testcoeffs_sel2 = experiment.get_betas_spam2(experiment.xtrain_sel, experiment.ytrain, experiment.groups_sel,lams[0:1],1,experiment.q,100000,tol)
yhats = get_reconstructed_vectors(testcoeffs_sel2[0],experiment.dg_M[4:5])

# %%
    def get_betas_spam3(xs, ys, groups, lambdas,n,q,itermax,tol):
        
        #n = xs.shape[0]
        p = len(np.unique(groups))
        lambdas = np.asarray(lambdas, dtype = np.float64)
        yadd = np.expand_dims(ys,1)
        groups = np.asarray(groups, dtype = np.int32) + 1
        W0 = np.zeros((xs.shape[1], yadd.shape[1]), dtype = np.float32)
        Xsam = np.asfortranarray(xs,dtype=np.float32)
        Ysam = np.asfortranarray(yadd,dtype=np.float32)
        coeffs= np.zeros((len(lambdas),q,n,p))
        for i in range(len(lambdas)):
            #alpha = spams.fistaFlat(Xsam,Dsam2,alpha0sam,ind_groupsam,lambda1 = lambdas[i],mode = mode,itermax = itermax,tol = tol,numThreads = numThreads, regul = "group-lasso-l2")
            #spams.fistaFlat(Y,X,W0,TRUE,numThreads = 1,verbose = TRUE,lambda1 = 0.05, it0 = 10, max_it = 200,L0 = 0.1, tol = 1e-3, intercept = FALSE,pos = FALSE,compute_gram = TRUE, loss = 'square',regul = 'l1')
            output = spams.fistaFlat(Ysam,Xsam,W0,True,groups = groups, numThreads = -1,verbose = True,lambda1 = lambdas[i], it0 = 100, max_it = itermax,L0 = 0.5, tol = tol, intercept = False,pos = False,compute_gram = True, loss = 'square',regul = 'group-lasso-l2',subgrad = False,a = 0.001, b = 100000, ista = True)
            coeffs[i,:,:,:] = np.reshape(output[0], (q,n,p))
            #print(output[1])
        return(coeffs)
    
    #import spams
    #help(spams.fistaFlat)
    testcoeffs_sel3 = get_betas_spam3(experiment.xtrain_sel, experiment.ytrain, experiment.groups_sel,lams[0:1],1,experiment.q,1000000,tol)
    yhats = get_reconstructed_vectors(testcoeffs_sel3[0],experiment.dg_M[4:5])

# %%
yhats
# Out:
# array([[[ 2076.85029836, -1830.04385497,   220.89082289],
#         [-1632.05446222,  1441.73381444,  -116.52887558]]])

# %%
plot_tangent_vecs(np.swapaxes(np.concatenate((experiment.df_M[4:5],yhats2sam, yhats),2),1,2), [0,1], [0], [1,1],['black','black','black','red','red','red','green','green','green'])

# %%
np.swapaxes(np.concatenate((experiment.df_M[4:5],yhats2sam,yhats2),2),1,2)
# Out:
# array([[[ 1.63279484e+03, -2.20349397e+03],
#         [-1.36525338e+03,  2.04234750e+03],
#         [ 1.18480635e+03,  1.12948810e+03],
#         [ 2.04052904e+03, -1.60968382e+03],
#         [-1.79818687e+03,  1.42378548e+03],
#         [ 2.24899711e+02, -1.05422562e+02],
#         [-3.70461582e+04, -5.09265580e+04],
#         [ 3.78759428e+04,  5.16350992e+04],
#         [ 1.47868473e+05,  1.83599812e+05]]])

# %%
plot_tangent_vecs(np.swapaxes(np.concatenate((experiment.df_M[1:2],yhats2sam),2),1,2), [0,1], [0], [1,1], ['red','red','red','black','black','black'])

# %%
experiment.ytrain
# Out:
# array([ 1632.79483584, -2203.49397061, -1365.25338213,  2042.34750354,
#         1184.80635464,  1129.48809936])

# %%
experiment.df_M[2]
# Out:
# array([[-1522.54938462,   989.00970867, -1501.27982179],
#        [-1024.66137415,  1036.7136053 ,  2371.31954156]])

# %%
datsss = np.random.multivariate_normal(np.zeros(2), np.identity(2), 1000)

# %%
datsss = datsss / np.expand_dims(np.linalg.norm(datsss, axis = 1),1)

# %%
z = np.random.multivariate_normal(np.zeros(1), 10*np.identity(1), 1000)

# %%
fig = plt.scatter

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(1, 1,1, projection='3d')
ax.scatter(datsss[:,0],datsss[:,1], z)
ax.set_axis_off()
# Out:
# <img src="data:image/png;base64,..." width="1079.999976591631">

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(1, 1,1, projection='3d')
ax.scatter(datsss[:,0],datsss[:,1], z)
ax.set_axis_off()
