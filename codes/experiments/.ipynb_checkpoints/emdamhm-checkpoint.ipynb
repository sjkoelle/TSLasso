# %%
import matplotlib
matplotlib.use('Agg')
import os
import datetime
import numpy as np
import dill as pickle
import random
import sys

workingdirectory = os.popen('git rev-parse --show-toplevel').read()[:-1]
sys.path.append(workingdirectory)
os.chdir(workingdirectory)

from codes.geometer.RiemannianManifold import RiemannianManifold

# %%
asdf = np.load('/Users/samsonkoelle/Desktop/eMDA-Me-H-Me_anglespca_pca50.npy')

# %%
b = RiemannianManifold(asdf,2)

# %%
diffusion_time = 1
#diffusion_time = 3
dim = 2
#b.geom = b.compute_geom(diffusion_time, 500)
b.geom = b.compute_geom(diffusion_time, 1000)
c = b.get_embedding3(b.geom, 5, diffusion_time, dim)

# %%
#diffusion_time = 1
diffusion_time = 3
dim = 2
#b.geom = b.compute_geom(diffusion_time, 500)
b.geom = b.compute_geom(diffusion_time, 1000)
c = b.get_embedding3(b.geom, 5, diffusion_time, dim)
# Out:
# initializing Geometry
# executing laplacian.compute_laplacian_matrix
# executing Laplacian.laplacian_matrix
# pre _compute_laplacian
# executing GeometricLaplacian._compute_laplacian
# executing _normalize_laplacian
# executing _normalize_laplacian
# post _compute_laplacian
# executing laplacian.compute_laplacian_matrix
# executing Laplacian.laplacian_matrix
# pre _compute_laplacian
# executing GeometricLaplacian._compute_laplacian
# executing _normalize_laplacian
# executing _normalize_laplacian
# post _compute_laplacian
# /Users/samsonkoelle/anaconda3/envs/py35021518/lib/python3.5/site-packages/megaman/geometry/rmetric.py:95: RuntimeWarning: divide by zero encountered in reciprocal
#   Einv = E**(-1)

# %%
#dt 3
# %matplotlib inline
n = c.data.shape[0]
c.plot([0,1],list(range(n)),np.ones(n), .1,.1, None)

# %%
#dt 4
# %matplotlib inline
n = c.data.shape[0]
c.plot([0,2],list(range(n)),np.ones(n), .1,.1, None)

# %%
#dt 4
# %matplotlib inline
n = c.data.shape[0]
c.plot([0,1],list(range(n)),np.ones(n), .1,.1, None)

# %%
#dt1

# %%
# %matplotlib inline
n = c.data.shape[0]
c.plot([0,1],list(range(n)),np.ones(n), .1,.1, None)

# %%
# %matplotlib inline
n = c.data.shape[0]
c.plot([0,1,2],list(range(n)),np.ones(n), .1,.1, None)

# %%
# %matplotlib inline
n = c.data.shape[0]
c.plot([0,1,2],list(range(n)),np.ones(n), .1,1, None)

# %%
# %matplotlib inline
n = c.data.shape[0]
c.plot([3,4],list(range(n)),np.ones(n), .1,1, None)

# %%
# %matplotlib inline
n = c.data.shape[0]
c.plot([0,1,3],list(range(n)),np.ones(n), .1,1, None)

# %%
# %matplotlib inline
n = c.data.shape[0]
c.plot([0,1,3],list(range(n)),np.ones(n), .1,1, None)
